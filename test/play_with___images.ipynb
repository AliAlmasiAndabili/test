# %% [markdown]
# <a href="https://colab.research.google.com/github/AliAlmasiAndabili/test/blob/main/test/play_with___images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://blog-fr.orson.io/wp-content/uploads/2017/06/jpeg-ou-png.jpg
# Out:
# --2022-12-12 15:56:05--  https://blog-fr.orson.io/wp-content/uploads/2017/06/jpeg-ou-png.jpg
# Resolving blog-fr.orson.io (blog-fr.orson.io)... 109.234.165.69
# Connecting to blog-fr.orson.io (blog-fr.orson.io)|109.234.165.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68734 (67K) [image/jpeg]
# Saving to: ‘jpeg-ou-png.jpg’
#
# jpeg-ou-png.jpg     100%[===================>]  67.12K   233KB/s    in 0.3s
#
# 2022-12-12 15:56:06 (233 KB/s) - ‘jpeg-ou-png.jpg’ saved [68734/68734]

# %%
# !ls
# Out:
# jpeg-ou-png.jpg  sample_data

# %%
from PIL import Image

# %%
pillow_im = Image.open('jpeg-ou-png.jpg')

# %%
import numpy as np

# %%
np_im = np.array(pillow_im)

# %%
Image.fromarray(np_im , 'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=900x681 at 0x7FD5E5864400>

# %%
h, w, ch = np_im.shape
np_im[:h//2,:w//2, 2] = 200

# %%
Image.fromarray(np_im , 'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=900x681 at 0x7FD5E150AE50>

# %%
ex = pillow_im.resize((w//2,h//2))
ex
# Out:
# <PIL.Image.Image image mode=RGB size=450x340 at 0x7FD5DFF231C0>
